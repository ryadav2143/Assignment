# %%
Q1. List any five functions of the pandas library with execution?
Ans:
    1.READ CSV
    2.HEAD
    3.TAIL
    4.DESCRIBE
    5.CATEGORICAL

# %%
1.
import pandas as pd
data = pd.read_csv('new.csv')
data
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
2.data.head()
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %%
3.data.tail()
# Out:
#     id  location_id  program_id         accepted_payments  \
# 18  19           19         NaN                       NaN
# 19  20           20         NaN                       NaN
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                             application_process  \
# 18                    NaN  Call for screening appointment (650-347-3648).
# 19                    NaN                                        Walk in.
# 20                    NaN                 By phone during business hours.
# 21  Fotos para pasaportes               Walk in or apply by phone or mail
# 22                    NaN               Walk in or apply by phone or mail
#
#                                              audience  \
# 18                                                NaN
# 19                                                NaN
# ...

# %%
4.data.describe()
# Out:
#              id  location_id  program_id
# count  23.00000    23.000000         0.0
# mean   12.00000    11.956522         NaN
# std     6.78233     6.711444         NaN
# min     1.00000     1.000000         NaN
# 25%     6.50000     6.500000         NaN
# 50%    12.00000    12.000000         NaN
# 75%    17.50000    17.500000         NaN
# max    23.00000    22.000000         NaN

# %%
5.pd.Categorical(data['languages'])
# Out:
# [NaN, NaN, NaN, NaN, NaN, ..., NaN, NaN, NaN, 'Spanish', NaN]
# Length: 23
# Categories (1, object): ['Spanish']

# %%
Q2. Given a Pandas DataFrame df with columns 'A', 'B', and 'C', write a Python function to re-index the
DataFrame with a new index that starts from 1 and increments by 2 for each row?
Ans:
import pandas as pd

def reindex_custom(df):
    new_index = range(1, len(df) * 2 + 1, 2) 
    df_reindexed = df.set_index(pd.Index(new_index))
    return df_reindexed

data = {'A': [10, 20, 30, 40],
        'B': [15, 25, 35, 45],
        'C': [18, 28, 38, 48]}

df = pd.DataFrame(data)

reindexed_df = reindex_custom(df)
print(reindexed_df)
# Out:
#     A   B   C
# 1  10  15  18
# 3  20  25  28
# 5  30  35  38
# 7  40  45  48

# %%
Q3. You have a Pandas DataFrame df with a column named 'Values'. Write a Python function that
iterates over the DataFrame and calculates the sum of the first three values in the 'Values' column. The
function should print the sum to the console?
Ans:
import pandas as pd
data={'values':[10,20,30,40,50,60]}
df = pd.DataFrame(data)
df['values'].head(3).sum()
# Out:
# 60

# %%
Q4. Given a Pandas DataFrame df with a column 'Text', write a Python function to create a new column
'Word_Count' that contains the number of words in each row of the 'Text' column?
Ans:
data = {'Text': ["Hello, this is a sample sentence.",
                 "Python programming is fun.",
                 "Data analysis using Pandas."]}
df = pd.DataFrame(data)
df['Word_count']=df['Text'].apply(lambda x:len(x.split()))
df
# Out:
#                                 Text  Word_count
# 0  Hello, this is a sample sentence.           6
# 1         Python programming is fun.           4
# 2        Data analysis using Pandas.           4

# %%
Q5. How are DataFrame.size() and DataFrame.shape() different?
Ans:
DataFrame.size:
DataFrame.size returns the total number of elements in the DataFrame, which is calculated by multiplying the number of rows by the 
number of columns.
This attribute returns a single integer value representing the total count of elements in the DataFrame.
It does not consider the data types of the elements; it simply counts the cells in the DataFrame.
DataFrame.size returns the total count of elements (rows * columns) as a single integer.

DataFrame.shape:
DataFrame.shape returns a tuple representing the dimensions of the DataFrame.
The tuple contains two values: the number of rows (axis 0) and the number of columns (axis 1) in the DataFrame.
It gives you a more intuitive understanding of the DataFrame's structure, as it provides the row and column count.
DataFrame.shape returns a tuple containing the number of rows and number of columns as separate values.

# %%
Q6. Which function of pandas do we use to read an excel file?
Ans:
    To read an Excel file using Pandas, you can use the read_excel() function. This function allows you to read data from Excel files
    (both .xls and .xlsx formats) and create a DataFrame from the data in the Excel sheet(s).
    
import pandas as pd
data = pd.read_excel('new.xls')

The read_excel() function reads the data from the Excel file and creates a DataFrame.

# %%
Q7. You have a Pandas DataFrame df that contains a column named 'Email' that contains email
addresses in the format 'username@domain.com'. Write a Python function that creates a new column
'Username' in df that contains only the username part of each email address.

The username is the part of the email address that appears before the '@' symbol. For example, if the
email address is 'john.doe@example.com', the 'Username' column should contain 'john.doe'. Your
function should extract the username from each email address and store it in the new 'Username'
column.
Ans:
import pandas as pd
data = {'Email': ['john.doe@example.com',
                  'jane.smith@example.com',
                  'alice.wonderland@example.com']}

df = pd.DataFrame(data)
df['Username'] = df['Email'].str.split('@').str[0]
df
# Out:
#                           Email          Username
# 0          john.doe@example.com          john.doe
# 1        jane.smith@example.com        jane.smith
# 2  alice.wonderland@example.com  alice.wonderland

# %%
Q8. You have a Pandas DataFrame df with columns 'A', 'B', and 'C'. Write a Python function that selects
all rows where the value in column 'A' is greater than 5 and the value in column 'B' is less than 10. The
function should return a new DataFrame that contains only the selected rows?
Ans:
import pandas as pd

def select_rows(df):
    selected_rows = df[(df['A'] > 5) & (df['B'] < 10)]
    return selected_rows
data = {'A': [3, 8, 6, 2, 9],
        'B': [5, 2, 9, 3, 1],
        'C': [1, 7, 4, 5, 2]}

df = pd.DataFrame(data)
selected_df = select_rows(df)
print(selected_df)
# Out:
#    A  B  C
# 1  8  2  7
# 2  6  9  4
# 4  9  1  2

# %%
Q9. Given a Pandas DataFrame df with a column 'Values', write a Python function to calculate the mean,
median, and standard deviation of the values in the 'Values' column?
Ans:
data = {'Values': [10, 20, 30, 40, 50]}
df = pd.DataFrame(data)
print(df['Values'].mean())
print(df['Values'].median())
print(df['Values'].std())
# Out:
# 30.0
# 30.0
# 15.811388300841896

# %%
Q10. Given a Pandas DataFrame df with a column 'Sales' and a column 'Date', write a Python function to
create a new column 'MovingAverage' that contains the moving average of the sales for the past 7 days
for each row in the DataFrame. The moving average should be calculated using a window of size 7 and
should include the current day?
Ans:
data = {'Sales': [50, 60, 70, 80, 90, 100, 110, 120, 130, 140],
        'Date': ['2023-08-01', '2023-08-02', '2023-08-03', '2023-08-04', '2023-08-05',
                 '2023-08-06', '2023-08-07', '2023-08-08', '2023-08-09', '2023-08-10']}
df= pd.DataFrame(data)
df['MovingAverage']=df['Sales'].rolling(window=7).mean()
df
# Out:
#    Sales        Date  MovingAverage
# 0     50  2023-08-01            NaN
# 1     60  2023-08-02            NaN
# 2     70  2023-08-03            NaN
# 3     80  2023-08-04            NaN
# 4     90  2023-08-05            NaN
# 5    100  2023-08-06            NaN
# 6    110  2023-08-07           80.0
# 7    120  2023-08-08           90.0
# 8    130  2023-08-09          100.0
# 9    140  2023-08-10          110.0

# %%
Q11. You have a Pandas DataFrame df with a column 'Date'. Write a Python function that creates a new
column 'Weekday' in the DataFrame. The 'Weekday' column should contain the weekday name (e.g.
Monday, Tuesday) corresponding to each date in the 'Date' column?
Ans:
import pandas as pd
data=pd.date_range(start ='2023-08-20',end = '2023-08-25')
df =pd.DataFrame({'date':data})
df['Weekday']=df['date'].dt.strftime('%A')
df
# Out:
#         date    Weekday
# 0 2023-08-20     Sunday
# 1 2023-08-21     Monday
# 2 2023-08-22    Tuesday
# 3 2023-08-23  Wednesday
# 4 2023-08-24   Thursday
# 5 2023-08-25     Friday

# %%
Q12. Given a Pandas DataFrame df with a column 'Date' that contains timestamps, write a Python
function to select all rows where the date is between '2023-01-01' and '2023-01-31'?
Ans:
import pandas as pd

def select_rows_in_date_range(df, start_date, end_date):
    mask = (df['Date'] >= start_date) & (df['Date'] <= end_date)
    selected_rows = df[mask]
    return selected_rows

data = {'Date': ['2023-01-15', '2023-02-10', '2023-01-05', '2023-01-25', '2023-02-20']}
df = pd.DataFrame(data)
df['Date'] = pd.to_datetime(df['Date']) 

start_date = '2023-01-01'
end_date = '2023-01-31'
selected_df = select_rows_in_date_range(df, start_date, end_date)
selected_df
# Out:
#         Date
# 0 2023-01-15
# 2 2023-01-05
# 3 2023-01-25

# %%
Q13. To use the basic functions of pandas, what is the first and foremost necessary library that needs to
be imported?
Ans:
The first and foremost necessary library that needs to be imported to use the basic functions of Pandas is the Pandas library itself. You can
import it using the following import statement:

import pandas as pd

By convention, the alias pd is commonly used for the Pandas library. Once you've imported Pandas, you can access its various functions and classes
to perform data manipulation and analysis using DataFrames and Series.
